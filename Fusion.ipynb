# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt

# Load the .mat file
data = loadmat("/content/drive/MyDrive/Biometrics/templates/CASIA1/99/099_1_2.jpg.mat")

# Check the variables in the loaded data
print(data.keys())

print(data.keys())

# Assuming one of the variables contains the image data, let's try to display them
plt.subplot(1, 2, 1)
plt.imshow(data['template'])
plt.title('Template')

plt.subplot(1, 2, 2)
plt.imshow(data['mask'])
plt.title('Mask')

plt.show()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'template', 'mask'])
# dict_keys(['__header__', '__version__', '__globals__', 'template', 'mask'])

# %% [markdown]
# ##Importing fingerprint and iris notebooks and Libraries required

# %%
# %run "/content/drive/MyDrive/Biometrics/FingerPrintPractice.ipynb"
# %run "/content/drive/MyDrive/Biometrics/IRISPractice.ipynb"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=96x103>
# <PIL.Image.Image image mode=RGB size=96x103>
# Matching result: 32812856.0
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['/content/drive/MyDrive/Biometrics/CASIA1/99/099_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/99/099_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/73/073_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/73/073_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/49/049_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/49/049_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/72/072_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/72/072_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/87/087_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/87/087_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/68/068_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/68/068_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/50/050_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/50/050_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/61/061_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/61/061_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/67/067_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/67/067_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/52/052_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/52/052_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/96/096_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/96/096_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/82/082_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/82/082_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/78/078_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/78/078_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/84/084_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/84/084_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/54/054_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/54/054_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/81/081_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/81/081_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/75/075_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/75/075_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/69/069_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/69/069_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/77/077_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/77/077_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/93/093_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/93/093_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/58/058_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/58/058_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/60/060_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/60/060_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/76/076_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/76/076_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/55/055_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/55/055_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/95/095_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/95/095_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/48/048_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/48/048_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/83/083_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/83/083_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/86/086_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/86/086_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/44/044_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/44/044_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/62/062_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/62/062_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/64/064_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/64/064_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/43/043_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/43/043_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/56/056_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/56/056_1_1.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/59/059_1_2.jpg', '/content/drive/MyDrive/Biometrics/CASIA1/59/0 ...
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# Warning: Grid coordinates are out of bounds.
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# here
# here
# here
# here
# Warning: Grid coordinates are out of bounds.
# Warning: Grid coordinates are out of bounds.
# here
# here
# Warning: Grid coordinates are out of bounds.
# here
# Warning: Grid coordinates are out of bounds.
# here
# here
# 200 200
# 99
# 99
# 73
# 73
# 49
# 49
# 72
# 72
# 87
# 87
# 68
# 68
# 50
# 50
# 61
# 61
# 67
# 67
# 52
# 52
# 96
# 96
# 82
# 82
# 78
# 78
# 84
# 84
# 54
# 54
# 81
# 81
# 75
# 75
# 69
# 69
# 77
# 77
# 93
# 93
# 58
# 58
# 60
# 60
# 76
# 76
# 55
# 55
# 95
# 95
# 48
# 48
# 83
# 83
# 86
# 86
# 44
# 44
# 62
# 62
# 64
# 64
# 43
# 43
# 56
# 56
# 59
# 59
# 90
# 90
# 47
# 47
# 85
# 85
# 45
# 45
# 46
# 46
# 66
# 66
# 92
# 92
# 97
# 97
# 98
# 98
# 51
# 51
# 79
# 79
# 71
# 71
# 40
# 40
# 74
# 74
# 63
# 63
# 91
# 91
# 65
# 65
# 53
# 53
# 80
# 80
# 57
# 57
# 70
# 70
# 42
# 42
# 94
# 94
# 88
# 88
# 41
# 41
# 89
# 89
# 10
# 10
# 11
# 11
# 12
# 12
# 13
# 13
# 14
# 14
# 15
# 15
# 16
# 16
# 17
# 17
# 18
# 18
# 19
# 19
# 20
# 20
# 21
# 21
# 22
# 22
# 23
# 23
# 24
# 24
# 25
# 25
# 26
# 26
# 27
# 27
# 28
# 28
# 29
# 29
# 30
# 30
# 31
# 31
# 32
# 32
# 33
# 33
# 34
# 34
# 35
# 35
# 36
# 36
# 37
# 37
# 38
# 38
# 39
# 39
# 00
# 00
# 03
# 03
# 02
# 02
# 01
# 01
# 09
# 09
# 08
# 08
# 06
# 06
# 07
# 07
# 05
# 05
# 04
# 04

# %%
import cv2
import numpy as np
import skimage.morphology
from skimage.morphology import convex_hull_image, erosion
from skimage.morphology import square
import math
from google.colab.patches import cv2_imshow


import os
from glob import glob
from tqdm import tqdm
from time import time
from scipy.io import savemat
from multiprocessing import cpu_count, Pool

from scipy import signal
from scipy.ndimage import convolve
from skimage.transform import radon
import numpy as np
import multiprocessing as mp


from os import listdir
from cv2 import imread
from multiprocessing import Pool, cpu_count
from itertools import repeat
from fnmatch import filter
import scipy.io as sio
import os
import warnings
warnings.filterwarnings("ignore")
import numpy as np
from scipy.signal import convolve2d

# %% [markdown]
# ##Score Level Fusion

# %%
img = cv2.imread('/content/drive/MyDrive/Biometrics/Real/172__M_Left_index_finger.BMP', 0)				# read the input image --> You can enhance the fingerprint image using the "fingerprint_enhancer" library
orgimg,FeaturesTerminations, FeaturesBifurcations = extract_minutiae_features(img, spuriousMinutiaeThresh=10, invertImage = False, showResult=True, saveResult = True)
img.shape
database_features = FeaturesTerminations + FeaturesBifurcations  # Database features
# Out:
# <PIL.Image.Image image mode=RGB size=96x103>

# %%
img = cv2.imread('/content/drive/MyDrive/Biometrics/Altered/172__M_Left_index_finger_Zcut.BMP', 0)				# read the input image --> You can enhance the fingerprint image using the "fingerprint_enhancer" library
alteredimg, FeaturesTerminations, FeaturesBifurcations = extract_minutiae_features(img, spuriousMinutiaeThresh=10, invertImage = False, showResult=True, saveResult = True)
img.shape
test_features = FeaturesTerminations + FeaturesBifurcations  # Test features
# Out:
# <PIL.Image.Image image mode=RGB size=96x103>
